# %% [markdown]
# # LAB | Error Handling in Python
#
# ## Overview
# This exercise notebook will help you practice error handling in Python using exceptions. You will write programs that handle various types of exceptions to ensure your code runs smoothly and handles errors gracefully.

# %% [markdown]
# ### Exercise 1: Handle ZeroDivisionError
# Write a Python program to handle a `ZeroDivisionError` exception when dividing a number by zero.

# %%
# Your code here
total = 0
num = 99
try:
    result = num/total
except:
    print("Caught a ZeroDivisionError")
# Out:
# Caught a ZeroDivisionError

# %% [markdown]
# ### Exercise 2: Raise ValueError for Invalid Input
# Write a Python program that prompts the user to input an integer and raises a `ValueError` exception if the input is not a valid integer.

# %%
# Example to show ValueError and how to handle it

user_input = input("Please enter an integer")

if type(user_input) == int:
    print(f"Received input from the user {user_input}")
else:
    raise ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       4
#       5 if type(user_input) == int:
#       6     print(f"Received input from the user {user_input}")
#       7 else:
# ----> 8     raise ValueError
#       9
#
# ValueError:

# %% [markdown]
# ### Exercise 3: Handle FileNotFoundError
# Write a Python program that opens a file and handles a `FileNotFoundError` exception if the file does not exist.

# %%
# Code to demonstrate FileNotFoundError

location = "test_file.txt"
try:
    with open(location, 'r', encoding="utf8") as f:
        df = f.read()
except:
    print("File not found!")
# Out:
# File not found!

# %% [markdown]
# ### Exercise 4: Raise TypeError for Non-Numerical Input
# Write a Python program that prompts the user to input two numbers and raises a `TypeError` exception if the inputs are not numerical.

# %%
# Code to demonstrate TypeError and its handling

input_a = int(input("Enter the first number: "))
input_b = input("Enter the second number: ")

try:
    result = input_a + input_b
    print(result)
except:
    print("User input Type mismatch found!")
    raise TypeError
# Out:
# User input Type mismatch found!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       9 except:
#      10     print("User input Type mismatch found!")
# ---> 11     raise TypeError
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       7     result = input_a + input_b
#       8     print(result)
#       9 except:
#      10     print("User input Type mismatch found!")
# ---> 11     raise TypeError
#
# TypeError:

# %% [markdown]
# ### Exercise 5: Handle PermissionError
# Write a Python program that opens a file and handles a `PermissionError` exception if there is a permission issue.

# %%
# Code to demonstrate PermissionError
location = "../permissions.txt"
try:
    with open(location, 'r', encoding="utf8") as f:
        df = f.read()
        f.write("Testing writing to a file!")
except:
    print("Write permission is not available for the file!")
# Out:
# Write permission is not available for the file!

# %% [markdown]
# ### Exercise 6: Handle IndexError in List Operations
# Write a Python program that executes an operation on a list and handles an `IndexError` exception if the index is out of range.

# %%
# Code to demostrate IndexError
nums = [1, 3, 5, 6, 8]

try:
    for i in range(1, 10):
        print(num(i)+10)
except:
    print("Index out of range!", IndexError)
# Out:
# Index out of range! <class 'IndexError'>

# %% [markdown]
# ### Exercise 7: Handle KeyboardInterrupt Exception
# Write a Python program that prompts the user to input a number and handles a `KeyboardInterrupt` exception if the user cancels the input.

# %%
# Code to demonstrate KeyboardInterrupt exception

try:
    name = input("Enter your name: ")
except:
    print("Caught error")

# %% [markdown]
# ### Exercise 8: Handle ArithmeticError
# Write a Python program that executes division and handles an `ArithmeticError` exception if there is an arithmetic error.

# %%
# Code to demostrate ArithmeticError exception

a = 10
b = 0
try:
    res = a / b
except:
    print("Caught arithmetic error", ArithmeticError)
# Out:
# Caught arithmetic error <class 'ArithmeticError'>

# %% [markdown]
# ### Exercise 9: Handle UnicodeDecodeError
# Write a Python program that opens a file and handles a `UnicodeDecodeError` exception if there is an encoding issue.

# %%
# Code to demonstrate and handle UnicodeDecodeError
t = b"a".decode("ascii")

# Produces error
try:
    t1 = b"a\xf1".decode("ascii")
except:
    print(UnicodeDecodeError)
# Out:
# <class 'UnicodeDecodeError'>

# %% [markdown]
# ### Exercise 10: Handle AttributeError
# Write a Python program that executes an operation on an object and handles an `AttributeError` exception if the attribute does not exist.

# %%
# Code to demostrate AttributeError exception
num = 10
try:
    num.append(5)
except:
    print(AttributeError)
# Out:
# <class 'AttributeError'>

# %% [markdown]
# ## Bonus Exercises
#
# ### Bonus Exercise 1: Handle Multiple Exceptions
# Write a Python program that demonstrates handling multiple exceptions in one block.

# %%
# Your code here

t = b"a".decode("ascii")
num = 10
try:
    num.append(5)
    t1 = b"a\xf1".decode("ascii")
except AttributeError:
    print("Caught Attribute error", AttributeError)
except UnicodeDecodeError:
    print("Caught unicode decode error", UnicodeDecodeError)
# Out:
# Caught Attribute error <class 'AttributeError'>

# %% [markdown]
# ### Bonus Exercise 2: Create Custom Exception
# Create a custom exception class and raise it in your code when certain conditions are met.

# %%
# Your code here

class MyCustomError(Exception):
    def __init__(self, message, error_code):
        super().__init__(message)
        self.message = message
        self.error_code = error_code

    def __str__(self):
        return f"{self.message} (Error Code: {self.error_code})"

err = MyCustomError("Invalid operation", 400)
print(err)
# Out:
# Invalid operation (Error Code: 400)

# %% [markdown]
# ### Bonus Exercise 3: Validate User Input with Exception Handling
# Write a program that repeatedly prompts the user for valid input until they provide it, using exception handling to manage invalid inputs.

# %%
# Your code here

# %% [markdown]
# ### Bonus Exercise 4: Log Errors to File
# Modify your error handling to log errors to a text file instead of printing them to the console.

# %%
# Your code here
location = "../log.txt"
num = 99
with open(location, 'w+', encoding="utf8") as f:
    df = f.read()
try:
    total = num / 0
except:
    with open(location, 'w+', encoding="utf8") as f:
        f.write("Divide by zero error occured")

# %% [markdown]
# ### Bonus Exercise 5: Retry Logic on Exception
# Implement retry logic for operations that could fail, allowing users to try again after encountering an error.

# %%
# Your code here
